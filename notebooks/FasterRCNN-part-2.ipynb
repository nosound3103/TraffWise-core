# %%
import shutil
shutil.copy("/kaggle/input/vehicle-detection-v1/training_log.csv", "/kaggle/working/training_log.csv")
# Out:
# '/kaggle/working/training_log.csv'

# %%
# %%writefile ddp.py

import csv
import os
import torch
import torchvision
import torchmetrics
import numpy as np
import torchvision.transforms.functional as F
from PIL import Image
from typing import Dict, List, Tuple
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from tqdm import tqdm
from torch.optim import AdamW, SGD
from torchmetrics.detection.mean_ap import MeanAveragePrecision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.transform import GeneralizedRCNNTransform
from torchvision.models.detection.backbone_utils import BackboneWithFPN
from torchvision.models import mobilenet_v3_small
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.rpn import AnchorGenerator
import math
import torchvision.models as models
from torchvision.models import MobileNet_V3_Small_Weights
from torch.optim.lr_scheduler import ReduceLROnPlateau

# Import DDP related modules
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data.distributed import DistributedSampler
import torch.distributed as dist
import functools


data_transform = transforms.Compose([
    transforms.Resize(size=(640, 640)),
    transforms.ToTensor()
])

class_to_idx = {
    "bus": 0, "car": 1, "motorbike": 2, "truck": 3,
}


class CustomDataset(Dataset):
    def __init__(self,
                 root_dir,
                 split="train",
                 class_to_idx=class_to_idx,
                 transform=data_transform):
        self.root_dir = root_dir
        self.split = split
        self.transform = transform
        self.class_to_idx = class_to_idx if class_to_idx else {}

        self.image_dir = os.path.join(root_dir, "images", split)
        self.label_dir = os.path.join(root_dir, "labels", split)

        self.image_files = [f for f in os.listdir(
            self.image_dir) if f.endswith(".jpg") or f.endswith(".png")]

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_filename = self.image_files[idx]
        img_path = os.path.join(self.image_dir, img_filename)

        img_name, _ = os.path.splitext(img_filename)
        label_path = os.path.join(self.label_dir, img_name + ".txt")

        img = Image.open(img_path).convert("RGB")
        original_width, original_height = img.size

        boxes = []
        labels = []

        if os.path.exists(label_path):
            with open(label_path, "r") as f:
                for line in f.readlines():
                    parts = line.strip().split()
                    if len(parts) < 5:
                        continue

                    class_id = int(parts[0])
                    x_center, y_center, w, h = map(float, parts[1:])

                    xmin = (x_center - w / 2) * original_width
                    ymin = (y_center - h / 2) * original_height
                    xmax = (x_center + w / 2) * original_width
                    ymax = (y_center + h / 2) * original_height

                    if xmin < xmax and ymin < ymax:
                        boxes.append([xmin, ymin, xmax, ymax])
                        labels.append(class_id + 1)

        boxes = torch.tensor(boxes, dtype=torch.float32)
        labels = torch.tensor(labels, dtype=torch.int64)
        target = {"boxes": boxes, "labels": labels}

        if len(boxes) == 0:
            boxes = torch.zeros((1, 4), dtype=torch.float32)
            labels = torch.zeros((1,), dtype=torch.int64)

        if self.transform:
            img = self.transform(img)

        new_width, new_height = 640, 640
        scale_x = new_width / original_width
        scale_y = new_height / original_height

        boxes[:, [0, 2]] *= scale_x
        boxes[:, [1, 3]] *= scale_y
        target["boxes"] = boxes

        return img, target


class CustomRCNNTransform(GeneralizedRCNNTransform):
    def __init__(self):
        super().__init__(min_size=640, max_size=640, image_mean=[
            0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225])

    def resize(self, image, target):
        image = F.resize(image, [640, 640])

        if target is not None and "boxes" in target:
            w_old, h_old = image.shape[-1], image.shape[-2]
            w_new, h_new = 640, 640
            scale_w = w_new / w_old
            scale_h = h_new / h_old
            target["boxes"][:, [0, 2]] *= scale_w
            target["boxes"][:, [1, 3]] *= scale_h
        return image, target


class FRCNN(torch.nn.Module):
    def __init__(self,
                 num_classes,
                 pretrained=MobileNet_V3_Small_Weights.DEFAULT):
        super(FRCNN, self).__init__()
        self.num_classes = num_classes
        self.backbone = self.get_backbone(pretrained)

        self.anchor_sizes = (32, 64, 128, 256)
        self.aspect_ratios = ((0.5, 1.0, 2.0),) * len(self.anchor_sizes)

        self.anchor_generator = AnchorGenerator(
            sizes=self.anchor_sizes,
            aspect_ratios=self.aspect_ratios
        )

        self.model = FasterRCNN(
            backbone=self.backbone,
            num_classes=num_classes,
            rpn_anchor_generator=self.anchor_generator
        )

        self.model.transform = CustomRCNNTransform()

    def get_backbone(self, pretrained):
        backbone = mobilenet_v3_small(weights=pretrained).features
        """Chọn lớp 2, 7, 12 trong backbone vì:
        - Cung cấp đặc trưng ở các mức độ phân giải và độ sâu khác nhau
        - Có số kênh đầu ra (24, 48, 576) phù hợp với thiết kế của FPN trong mã của bạn
        - Phân bố đều trong cấu trúc của MobileNetV3-Small để tối ưu hóa việc phát hiện đối tượng ở nhiều tỷ lệ"""
        return_layers = {'2': '0', '7': '1', '12': '2'}
        in_channels = [24, 48, 576]

        backbone.out_channels = 64
        fpn = BackboneWithFPN(
            backbone=backbone,
            return_layers=return_layers,
            in_channels_list=in_channels,
            out_channels=64
        )

        return fpn

    def forward(self, images, targets=None):
        if self.training:
            if targets is None:
                raise ValueError("In training mode, targets should be passed")
            return self.model(images, targets)
        else:
            return self.model(images)



# Define a custom collate function outside other functions
def detection_collate_fn(batch):
    return tuple(zip(*batch))


# Training loop with DDP - defined as top-level function
def train_one_epoch(model, optimizer, train_loader, device, rank):
    model.train()
    total_train_loss = 0.0
    total_loc_loss = 0.0  # Localization Loss
    total_cls_loss = 0.0  # Classification Loss
    
    if rank == 0:
        progress_bar = tqdm(train_loader, desc="Training", leave=False)
    else:
        progress_bar = train_loader
    
    for images, targets in progress_bar:
        images = [img.to(device) for img in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        optimizer.zero_grad()
        loss_dict = model(images, targets)
        
        # Trích xuất các thành phần loss
        loc_loss = loss_dict["loss_box_reg"] + loss_dict.get("loss_rpn_box_reg", 0.0)  # Localization Loss
        cls_loss = loss_dict["loss_classifier"]  # Classification Loss
        total_loss = sum(loss for loss in loss_dict.values())
        
        total_train_loss += total_loss.item()
        total_loc_loss += loc_loss.item()
        total_cls_loss += cls_loss.item()
        
        total_loss.backward()
        optimizer.step()
    
    # Tính trung bình qua tất cả batch
    train_loss = total_train_loss / len(train_loader)
    train_loc_loss = total_loc_loss / len(train_loader)
    train_cls_loss = total_cls_loss / len(train_loader)
    
    # Đồng bộ hóa giữa các GPU
    train_loss_tensor = torch.tensor(train_loss, device=device)
    train_loc_loss_tensor = torch.tensor(train_loc_loss, device=device)
    train_cls_loss_tensor = torch.tensor(train_cls_loss, device=device)
    dist.all_reduce(train_loss_tensor, op=dist.ReduceOp.SUM)
    dist.all_reduce(train_loc_loss_tensor, op=dist.ReduceOp.SUM)
    dist.all_reduce(train_cls_loss_tensor, op=dist.ReduceOp.SUM)
    
    world_size = dist.get_world_size()
    train_loss = train_loss_tensor.item() / world_size
    train_loc_loss = train_loc_loss_tensor.item() / world_size
    train_cls_loss = train_cls_loss_tensor.item() / world_size
    
    return train_loss, train_loc_loss, train_cls_loss

# Evaluation function - unchanged
def evaluate(model, val_loader, device, rank):
    model.eval()
    metric = MeanAveragePrecision(class_metrics=True, extended_summary=True).to(device)
    total_val_loss = 0.0
    total_loc_loss = 0.0  # Localization Loss
    total_cls_loss = 0.0  # Classification Loss
    
    if rank == 0:
        progress_bar = tqdm(val_loader, desc="Evaluating", leave=False)
    else:
        progress_bar = val_loader

    with torch.no_grad():
        for images, targets in progress_bar:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            model.train()  # Temporarily enable training mode for loss
            loss_dict = model(images, targets)
            
            # Trích xuất các thành phần loss
            loc_loss = loss_dict["loss_box_reg"] + loss_dict.get("loss_rpn_box_reg", 0.0)  # Localization Loss
            cls_loss = loss_dict["loss_classifier"]  # Classification Loss
            total_loss = sum(loss for loss in loss_dict.values())
            
            total_val_loss += total_loss.item()
            total_loc_loss += loc_loss.item()
            total_cls_loss += cls_loss.item()
            
            model.eval()  # Back to eval mode
            outputs = model(images)
            preds = [
                {"boxes": output["boxes"], "scores": output["scores"], "labels": output["labels"]}
                for output in outputs
            ]
            metric.update(preds, targets)

    # Tính toán kết quả từ metric
    results = metric.compute()
    map50 = torch.tensor(results["map_50"].item(), device=device)
    map95 = torch.tensor(results["map"].item(), device=device)
    map95_per_class = results["map_per_class"][results["map_per_class"] != -1].tolist()
    
    # Trích xuất precision và recall từng class
    iou_idx = 0  # IoU=0.5
    num_classes = len(map95_per_class)
    precision_tensor = results["precision"][iou_idx]  # Shape: (R, K, A, M)
    recall_tensor = results["recall"][iou_idx]  # Shape: (K, A, M)
    
    precision_per_class = [precision_tensor[:, cls, 0, :].mean().item() if not torch.isnan(precision_tensor[:, cls, 0, :]).all() else 0.0 for cls in range(num_classes)]
    recall_per_class = [recall_tensor[cls, 0, :].mean().item() if not torch.isnan(recall_tensor[cls, 0, :]).all() else 0.0 for cls in range(num_classes)]
    
    precision_avg = sum(precision_per_class) / len(precision_per_class) if precision_per_class else 0.0
    recall_avg = sum(recall_per_class) / len(recall_per_class) if recall_per_class else 0.0
    
    # Tính trung bình loss
    val_loss = total_val_loss / len(val_loader)
    val_loc_loss = total_loc_loss / len(val_loader)
    val_cls_loss = total_cls_loss / len(val_loader)
    
    # Đồng bộ hóa giữa các GPU
    dist.all_reduce(map50, op=dist.ReduceOp.SUM)
    dist.all_reduce(map95, op=dist.ReduceOp.SUM)
    dist.all_reduce(torch.tensor(val_loss, device=device), op=dist.ReduceOp.SUM)
    dist.all_reduce(torch.tensor(val_loc_loss, device=device), op=dist.ReduceOp.SUM)
    dist.all_reduce(torch.tensor(val_cls_loss, device=device), op=dist.ReduceOp.SUM)
    
    map95_per_class_tensor = torch.tensor(map95_per_class, device=device)
    precision_per_class_tensor = torch.tensor(precision_per_class, device=device)
    recall_per_class_tensor = torch.tensor(recall_per_class, device=device)
    dist.all_reduce(map95_per_class_tensor, op=dist.ReduceOp.SUM)
    dist.all_reduce(precision_per_class_tensor, op=dist.ReduceOp.SUM)
    dist.all_reduce(recall_per_class_tensor, op=dist.ReduceOp.SUM)
    
    world_size = dist.get_world_size()
    map50 = map50.item() / world_size
    map95 = map95.item() / world_size
    val_loss = val_loss / world_size
    val_loc_loss = val_loc_loss / world_size
    val_cls_loss = val_cls_loss / world_size
    map95_per_class = (map95_per_class_tensor / world_size).tolist()
    precision_per_class = (precision_per_class_tensor / world_size).tolist()
    recall_per_class = (recall_per_class_tensor / world_size).tolist()
    precision_avg = precision_avg / world_size
    recall_avg = recall_avg / world_size

    return map50, map95, val_loss, map95_per_class, precision_per_class, recall_per_class, precision_avg, recall_avg, val_loc_loss, val_cls_loss

# Main DDP training function with ReduceLROnPlateau
def train_ddp(rank, world_size, data_dir, num_classes, num_epochs, batch_size, lr, resume_from):
    # Setup DDP
    os.environ['MASTER_ADDR'] = 'localhost'
    os.environ['MASTER_PORT'] = '12355'
    dist.init_process_group("nccl", rank=rank, world_size=world_size)
    
    device = torch.device(f"cuda:{rank}")
    torch.cuda.set_device(device)

    # Initialize datasets and samplers
    train_dataset = CustomDataset(data_dir)
    val_dataset = CustomDataset(data_dir, split="val")

    train_sampler = DistributedSampler(
        train_dataset, 
        num_replicas=world_size, 
        rank=rank,
        shuffle=True
    )
    
    val_sampler = DistributedSampler(
        val_dataset, 
        num_replicas=world_size, 
        rank=rank,
        shuffle=False
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        sampler=train_sampler,
        num_workers=2,
        collate_fn=detection_collate_fn,
        pin_memory=True
    )
    
    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        sampler=val_sampler,
        num_workers=2,
        collate_fn=detection_collate_fn,
        pin_memory=True
    )

    # Create model
    model = FRCNN(num_classes=num_classes)
    model = model.to(device)
    model = torch.nn.parallel.DistributedDataParallel(model, device_ids=[rank], output_device=rank)

    # Create optimizer
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=lr,               # Initial learning rate (passed as argument)
        betas=(0.85, 0.999), # Adjusted beta1 for DDP
        weight_decay=0.01,
        eps=1e-8
    )
    
    # Create ReduceLROnPlateau scheduler (only on rank 0)
    scheduler = None
    if rank == 0:
        scheduler = ReduceLROnPlateau(
            optimizer,
            mode='min',       # Minimize validation loss
            factor=0.1,       # Reduce lr by 10x
            patience=5,       # Wait 5 epochs
            threshold=0.0001, # Minimum improvement
            min_lr=1e-6,      # Minimum learning rate
            verbose=True      # Print updates
        )

    # Load checkpoint if resuming
    best_map95 = 0
    start_epoch = 1
    
    if resume_from and os.path.exists(resume_from):
        map_location = {'cuda:%d' % 0: 'cuda:%d' % rank}
        checkpoint = torch.load(resume_from, map_location=map_location, weights_only=True)
        model.module.load_state_dict(checkpoint["model_state_dict"])
        optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
        start_epoch = checkpoint["epoch"] + 1
        best_map95 = checkpoint.get("best_map95", 0)
        if rank == 0 and "scheduler_state_dict" in checkpoint:
            scheduler.load_state_dict(checkpoint["scheduler_state_dict"])
        if rank == 0:
            print(f"Resuming from epoch {start_epoch} with best map95: {best_map95:.4f}")

    
    # Định nghĩa tên class
    class_names = ["bus", "car", "motorbike", "truck"]

    # CSV logging chỉ trên rank 0
    csv_filename = "training_log.csv"
    if rank == 0:
        if not os.path.exists(csv_filename) or not resume_from:
            with open(csv_filename, "w", newline="") as f:
                writer = csv.writer(f)
                headers = ["epoch", "train_loss", "train_loc_loss", "train_cls_loss", "val_loss", "val_loc_loss", "val_cls_loss", 
                           "mAP50", "mAP95", "precision_avg", "recall_avg"]
                for cls in class_names:
                    headers.append(f"mAP95_{cls}")
                    headers.append(f"precision_{cls}")
                    headers.append(f"recall_{cls}")
                headers.append("learning_rate")
                writer.writerow(headers)
    
    # Training loop
    for epoch in range(start_epoch, num_epochs + 1):
        train_sampler.set_epoch(epoch)
        val_sampler.set_epoch(epoch)
        
        train_loss, train_loc_loss, train_cls_loss = train_one_epoch(model, optimizer, train_loader, device, rank)
        map50, map95, val_loss, map95_per_class, precision_per_class, recall_per_class, precision_avg, recall_avg, val_loc_loss, val_cls_loss = evaluate(model, val_loader, device, rank)
        
        if rank == 0 and scheduler is not None:
            scheduler.step(val_loss)
        
        if rank == 0:
            checkpoint = {
                "epoch": epoch,
                "model_state_dict": model.module.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "best_map95": best_map95,
                "scheduler_state_dict": scheduler.state_dict() if scheduler else None
            }
            torch.save(checkpoint, "last_model.pt")
            
            if map95 > best_map95:
                best_map95 = map95
                torch.save(checkpoint, "best_model.pt")
            
            current_lr = optimizer.param_groups[0]['lr']
            with open(csv_filename, "a", newline="") as f:
                writer = csv.writer(f)
                row = [epoch, train_loss, train_loc_loss, train_cls_loss, val_loss, val_loc_loss, val_cls_loss, 
                       map50, map95, precision_avg, recall_avg]
                row.extend(map95_per_class)
                row.extend(precision_per_class)
                row.extend(recall_per_class)
                row.append(current_lr)
                writer.writerow(row)
            
            print(f"[Epoch {epoch}/{num_epochs}] "
                  f"Train Loss: {train_loss:.4f} (Loc: {train_loc_loss:.4f}, Cls: {train_cls_loss:.4f}) | "
                  f"Val Loss: {val_loss:.4f} (Loc: {val_loc_loss:.4f}, Cls: {val_cls_loss:.4f}) | "
                  f"mAP@50: {map50:.4f} | mAP@50:95: {map95:.4f} | "
                  f"Precision (Avg): {precision_avg:.4f} | Recall (Avg): {recall_avg:.4f} | LR: {current_lr:.6f}")
            for cls, m95, prec, rec in zip(class_names, map95_per_class, precision_per_class, recall_per_class):
                print(f"  {cls}: mAP@50:95: {m95:.4f} | Precision: {prec:.4f} | Recall: {rec:.4f}")
    
    dist.destroy_process_group()


# Single GPU training function
def train_single_gpu(data_dir, num_classes, num_epochs, batch_size, lr, resume_from=None):
    model = FRCNN(num_classes = num_classes).to(device)
    optimizer = SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=0.0005)
    
    # best_val_loss = float("inf")  # Đổi từ best_loss sang best_val_loss
    best_map95 = 0
    start_epoch = 1
    
    if resume_from and os.path.exists(resume_from):
        map_location = {'cuda:%d' % 0: 'cuda:%d' % rank}
        checkpoint = torch.load(resume_from, map_location=map_location, weights_only=True)
        model.module.load_state_dict(checkpoint["model_state_dict"])
        optimizer.load_state_dict(checkpoint["optimizer_state_dict"])
        start_epoch = checkpoint["epoch"] + 1
        # best_map95 = checkpoint.get("best_map95", 0) 
        print(f"Resuming from epoch {start_epoch} with best map95: {best_map95:.4f}")
    
    # Sửa header của CSV để thêm val_loss
    csv_filename = "training_log.csv"
    with open(csv_filename, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["epoch", "train_loss", "val_loss", "mAP50", "mAP95"])
    
    for epoch in range(start_epoch, num_epochs + 1):
        # Train
        model.train()
        total_train_loss = 0.0
        progress_bar = tqdm(train_loader, desc="Training", leave=False)
        for images, targets in progress_bar:
            images = [img.to(device) for img in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
            loss_dict = model(images, targets)
            loss = sum(loss for loss in loss_dict.values())
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()
            progress_bar.set_postfix(loss=loss.item())
        
        train_loss = total_train_loss / len(train_loader)
        
        # Evaluate với validation loss
        model.eval()
        metric = MeanAveragePrecision().to(device)
        total_val_loss = 0.0
        with torch.no_grad():
            for images, targets in tqdm(val_loader, desc="Evaluating", leave=False):
                images = [img.to(device) for img in images]
                targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
                # Tính validation loss
                model.train()  # Tạm thời bật training mode để tính loss
                loss_dict = model(images, targets)
                loss = sum(loss for loss in loss_dict.values())
                total_val_loss += loss.item()
                model.eval()  # Quay lại eval mode
                
                outputs = model(images)
                preds = [
                    {"boxes": output["boxes"], "scores": output["scores"], "labels": output["labels"]}
                    for output in outputs
                ]
                metric.update(preds, targets)
        
        val_loss = total_val_loss / len(val_loader)
        results = metric.compute()
        map50 = results["map_50"].item()
        map95 = results["map"].item()
        
        # Save checkpoints
        torch.save({
                    "epoch": epoch,
                    "model_state_dict": model.module.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "best_map95": best_map95# Sửa key
                }, "last_model.pt")
        
        if map95 > best_map95:
                    best_map95 = map95
                    torch.save({
                        "epoch": epoch,
                        "model_state_dict": model.module.state_dict(),
                        "optimizer_state_dict": optimizer.state_dict(),
                        "best_map95": best_map95
                    }, "best_model.pt")
        
        # Log cả train_loss và val_loss
        with open(csv_filename, "a", newline="") as f:
            writer = csv.writer(f)
            writer.writerow([epoch, train_loss, val_loss, map50, map95])
        
        print(f"[Epoch {epoch}/{num_epochs}] Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | mAP@50: {map50:.4f} | mAP@50:95: {map95:.4f}")


def main():
    # Set params
    world_size = torch.cuda.device_count()  # Number of GPUs available
    data_dir = '/kaggle/input/vehicle-detection-v1/combination/combination'
    num_classes = 5
    num_epochs = 150
    batch_size = 64
    lr = 1e-4
    resume_from = "/kaggle/input/vehicle-detection-v1/last_model.pt"
    
    if world_size > 1:
        print(f"Training with {world_size} GPUs using DDP")
        # Adjust batch size per GPU
        batch_size_per_gpu = batch_size // world_size
        
        # Use spawn method for starting processes
        mp.spawn(
            train_ddp,
            args=(world_size, data_dir, num_classes, num_epochs, batch_size_per_gpu, lr, resume_from),
            nprocs=world_size,
            join=True
        )
    else:
        print("Only one GPU detected, training without DDP")
        train_single_gpu(data_dir, num_classes, num_epochs, batch_size, lr, resume_from)


if __name__ == "__main__":
    # Ensure proper process initialization for CUDA
    mp.set_start_method('spawn', force=True)
    main()
# Out:
# Writing ddp.py

# %%
# !python ddp.py
# Out:
# Training with 2 GPUs using DDP
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████████████████████████████████| 9.83M/9.83M [00:00<00:00, 26.1MB/s]
# 100%|██████████████████████████████████████| 9.83M/9.83M [00:00<00:00, 23.2MB/s]
# Resuming from epoch 51 with best map95: 0.6488
# [Epoch 51/150] Train Loss: 0.2373 (Loc: 0.1553, Cls: 0.0725) | Val Loss: 0.1549 (Loc: 0.0952, Cls: 0.0522) | mAP@50: 0.9017 | mAP@50:95: 0.6626 | Precision (Avg): 0.3475 | Recall (Avg): 0.3646 | LR: 0.000010
#   bus: mAP@50:95: 0.6550 | Precision: 0.7838 | Recall: 0.8294
#   car: mAP@50:95: 0.7296 | Precision: 0.6527 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6135 | Precision: 0.6004 | Recall: 0.6291
#   truck: mAP@50:95: 0.6522 | Precision: 0.7430 | Recall: 0.7892
# [Epoch 52/150] Train Loss: 0.2361 (Loc: 0.1546, Cls: 0.0721) | Val Loss: 0.1554 (Loc: 0.0953, Cls: 0.0524) | mAP@50: 0.9012 | mAP@50:95: 0.6630 | Precision (Avg): 0.3475 | Recall (Avg): 0.3642 | LR: 0.000010
#   bus: mAP@50:95: 0.6531 | Precision: 0.7824 | Recall: 0.8272
#   car: mAP@50:95: 0.7307 | Precision: 0.6531 | Recall: 0.6694
#   motorbike: mAP@50:95: 0.6152 | Precision: 0.6009 | Recall: 0.6286
#   truck: mAP@50:95: 0.6531 | Precision: 0.7436 | Recall: 0.7880
# [Epoch 53/150] Train Loss: 0.2359 (Loc: 0.1544, Cls: 0.0721) | Val Loss: 0.1549 (Loc: 0.0952, Cls: 0.0520) | mAP@50: 0.9002 | mAP@50:95: 0.6628 | Precision (Avg): 0.3467 | Recall (Avg): 0.3640 | LR: 0.000010
#   bus: mAP@50:95: 0.6549 | Precision: 0.7825 | Recall: 0.8279
#   car: mAP@50:95: 0.7321 | Precision: 0.6528 | Recall: 0.6693
#   motorbike: mAP@50:95: 0.6150 | Precision: 0.6002 | Recall: 0.6279
#   truck: mAP@50:95: 0.6490 | Precision: 0.7383 | Recall: 0.7869
# [Epoch 54/150] Train Loss: 0.2350 (Loc: 0.1540, Cls: 0.0716) | Val Loss: 0.1546 (Loc: 0.0952, Cls: 0.0518) | mAP@50: 0.9012 | mAP@50:95: 0.6628 | Precision (Avg): 0.3470 | Recall (Avg): 0.3643 | LR: 0.000010
#   bus: mAP@50:95: 0.6536 | Precision: 0.7829 | Recall: 0.8292
#   car: mAP@50:95: 0.7301 | Precision: 0.6529 | Recall: 0.6694
#   motorbike: mAP@50:95: 0.6164 | Precision: 0.5999 | Recall: 0.6286
#   truck: mAP@50:95: 0.6512 | Precision: 0.7402 | Recall: 0.7874
# [Epoch 55/150] Train Loss: 0.2343 (Loc: 0.1533, Cls: 0.0715) | Val Loss: 0.1553 (Loc: 0.0951, Cls: 0.0525) | mAP@50: 0.9016 | mAP@50:95: 0.6631 | Precision (Avg): 0.3472 | Recall (Avg): 0.3643 | LR: 0.000010
#   bus: mAP@50:95: 0.6569 | Precision: 0.7833 | Recall: 0.8284
#   car: mAP@50:95: 0.7298 | Precision: 0.6531 | Recall: 0.6696
#   motorbike: mAP@50:95: 0.6150 | Precision: 0.6005 | Recall: 0.6279
#   truck: mAP@50:95: 0.6508 | Precision: 0.7403 | Recall: 0.7883
# [Epoch 56/150] Train Loss: 0.2340 (Loc: 0.1533, Cls: 0.0713) | Val Loss: 0.1546 (Loc: 0.0950, Cls: 0.0520) | mAP@50: 0.9003 | mAP@50:95: 0.6623 | Precision (Avg): 0.3469 | Recall (Avg): 0.3641 | LR: 0.000010
#   bus: mAP@50:95: 0.6505 | Precision: 0.7805 | Recall: 0.8254
#   car: mAP@50:95: 0.7310 | Precision: 0.6530 | Recall: 0.6698
#   motorbike: mAP@50:95: 0.6146 | Precision: 0.6004 | Recall: 0.6280
#   truck: mAP@50:95: 0.6531 | Precision: 0.7410 | Recall: 0.7894
# [Epoch 57/150] Train Loss: 0.2337 (Loc: 0.1531, Cls: 0.0712) | Val Loss: 0.1542 (Loc: 0.0949, Cls: 0.0517) | mAP@50: 0.9003 | mAP@50:95: 0.6639 | Precision (Avg): 0.3468 | Recall (Avg): 0.3640 | LR: 0.000010
#   bus: mAP@50:95: 0.6545 | Precision: 0.7808 | Recall: 0.8263
#   car: mAP@50:95: 0.7316 | Precision: 0.6527 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6138 | Precision: 0.6000 | Recall: 0.6272
#   truck: mAP@50:95: 0.6557 | Precision: 0.7412 | Recall: 0.7890
# [Epoch 58/150] Train Loss: 0.2332 (Loc: 0.1529, Cls: 0.0711) | Val Loss: 0.1550 (Loc: 0.0950, Cls: 0.0524) | mAP@50: 0.9011 | mAP@50:95: 0.6636 | Precision (Avg): 0.3472 | Recall (Avg): 0.3640 | LR: 0.000010
#   bus: mAP@50:95: 0.6530 | Precision: 0.7824 | Recall: 0.8276
#   car: mAP@50:95: 0.7315 | Precision: 0.6527 | Recall: 0.6689
#   motorbike: mAP@50:95: 0.6138 | Precision: 0.6007 | Recall: 0.6283
#   truck: mAP@50:95: 0.6563 | Precision: 0.7416 | Recall: 0.7873
# [Epoch 59/150] Train Loss: 0.2328 (Loc: 0.1526, Cls: 0.0711) | Val Loss: 0.1549 (Loc: 0.0950, Cls: 0.0522) | mAP@50: 0.9008 | mAP@50:95: 0.6637 | Precision (Avg): 0.3470 | Recall (Avg): 0.3639 | LR: 0.000010
#   bus: mAP@50:95: 0.6523 | Precision: 0.7815 | Recall: 0.8260
#   car: mAP@50:95: 0.7324 | Precision: 0.6530 | Recall: 0.6690
#   motorbike: mAP@50:95: 0.6151 | Precision: 0.6005 | Recall: 0.6283
#   truck: mAP@50:95: 0.6548 | Precision: 0.7410 | Recall: 0.7882
# [Epoch 60/150] Train Loss: 0.2325 (Loc: 0.1524, Cls: 0.0709) | Val Loss: 0.1547 (Loc: 0.0951, Cls: 0.0521) | mAP@50: 0.9013 | mAP@50:95: 0.6621 | Precision (Avg): 0.3470 | Recall (Avg): 0.3645 | LR: 0.000010
#   bus: mAP@50:95: 0.6517 | Precision: 0.7821 | Recall: 0.8284
#   car: mAP@50:95: 0.7307 | Precision: 0.6527 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6139 | Precision: 0.6004 | Recall: 0.6294
#   truck: mAP@50:95: 0.6521 | Precision: 0.7407 | Recall: 0.7888
# [Epoch 61/150] Train Loss: 0.2318 (Loc: 0.1520, Cls: 0.0706) | Val Loss: 0.1541 (Loc: 0.0947, Cls: 0.0517) | mAP@50: 0.9015 | mAP@50:95: 0.6634 | Precision (Avg): 0.3471 | Recall (Avg): 0.3643 | LR: 0.000010
#   bus: mAP@50:95: 0.6542 | Precision: 0.7840 | Recall: 0.8285
#   car: mAP@50:95: 0.7329 | Precision: 0.6527 | Recall: 0.6687
#   motorbike: mAP@50:95: 0.6145 | Precision: 0.6007 | Recall: 0.6283
#   truck: mAP@50:95: 0.6520 | Precision: 0.7395 | Recall: 0.7891
# [Epoch 62/150] Train Loss: 0.2317 (Loc: 0.1518, Cls: 0.0706) | Val Loss: 0.1549 (Loc: 0.0950, Cls: 0.0522) | mAP@50: 0.9010 | mAP@50:95: 0.6644 | Precision (Avg): 0.3474 | Recall (Avg): 0.3639 | LR: 0.000010
#   bus: mAP@50:95: 0.6548 | Precision: 0.7808 | Recall: 0.8246
#   car: mAP@50:95: 0.7323 | Precision: 0.6530 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6145 | Precision: 0.6006 | Recall: 0.6282
#   truck: mAP@50:95: 0.6561 | Precision: 0.7446 | Recall: 0.7891
# [Epoch 63/150] Train Loss: 0.2314 (Loc: 0.1518, Cls: 0.0704) | Val Loss: 0.1547 (Loc: 0.0950, Cls: 0.0521) | mAP@50: 0.9007 | mAP@50:95: 0.6639 | Precision (Avg): 0.3470 | Recall (Avg): 0.3640 | LR: 0.000010
#   bus: mAP@50:95: 0.6563 | Precision: 0.7832 | Recall: 0.8284
#   car: mAP@50:95: 0.7316 | Precision: 0.6527 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6155 | Precision: 0.5998 | Recall: 0.6276
#   truck: mAP@50:95: 0.6521 | Precision: 0.7404 | Recall: 0.7869
# [Epoch 64/150] Train Loss: 0.2311 (Loc: 0.1514, Cls: 0.0704) | Val Loss: 0.1551 (Loc: 0.0953, Cls: 0.0523) | mAP@50: 0.9011 | mAP@50:95: 0.6643 | Precision (Avg): 0.3469 | Recall (Avg): 0.3645 | LR: 0.000010
#   bus: mAP@50:95: 0.6559 | Precision: 0.7828 | Recall: 0.8285
#   car: mAP@50:95: 0.7327 | Precision: 0.6526 | Recall: 0.6687
#   motorbike: mAP@50:95: 0.6169 | Precision: 0.6007 | Recall: 0.6288
#   truck: mAP@50:95: 0.6518 | Precision: 0.7394 | Recall: 0.7899
# [Epoch 65/150] Train Loss: 0.2311 (Loc: 0.1515, Cls: 0.0703) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0525) | mAP@50: 0.9010 | mAP@50:95: 0.6645 | Precision (Avg): 0.3474 | Recall (Avg): 0.3640 | LR: 0.000010
#   bus: mAP@50:95: 0.6552 | Precision: 0.7819 | Recall: 0.8267
#   car: mAP@50:95: 0.7315 | Precision: 0.6528 | Recall: 0.6689
#   motorbike: mAP@50:95: 0.6153 | Precision: 0.6004 | Recall: 0.6277
#   truck: mAP@50:95: 0.6558 | Precision: 0.7438 | Recall: 0.7891
# [Epoch 66/150] Train Loss: 0.2304 (Loc: 0.1512, Cls: 0.0701) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0523) | mAP@50: 0.9006 | mAP@50:95: 0.6643 | Precision (Avg): 0.3470 | Recall (Avg): 0.3639 | LR: 0.000010
#   bus: mAP@50:95: 0.6544 | Precision: 0.7818 | Recall: 0.8260
#   car: mAP@50:95: 0.7331 | Precision: 0.6530 | Recall: 0.6691
#   motorbike: mAP@50:95: 0.6157 | Precision: 0.5999 | Recall: 0.6278
#   truck: mAP@50:95: 0.6541 | Precision: 0.7409 | Recall: 0.7880
# [Epoch 67/150] Train Loss: 0.2305 (Loc: 0.1512, Cls: 0.0701) | Val Loss: 0.1553 (Loc: 0.0950, Cls: 0.0525) | mAP@50: 0.9004 | mAP@50:95: 0.6637 | Precision (Avg): 0.3469 | Recall (Avg): 0.3641 | LR: 0.000001
#   bus: mAP@50:95: 0.6540 | Precision: 0.7814 | Recall: 0.8273
#   car: mAP@50:95: 0.7323 | Precision: 0.6528 | Recall: 0.6684
#   motorbike: mAP@50:95: 0.6158 | Precision: 0.6006 | Recall: 0.6285
#   truck: mAP@50:95: 0.6527 | Precision: 0.7401 | Recall: 0.7883
# [Epoch 68/150] Train Loss: 0.2304 (Loc: 0.1511, Cls: 0.0701) | Val Loss: 0.1553 (Loc: 0.0950, Cls: 0.0526) | mAP@50: 0.9005 | mAP@50:95: 0.6636 | Precision (Avg): 0.3470 | Recall (Avg): 0.3638 | LR: 0.000001
#   bus: mAP@50:95: 0.6548 | Precision: 0.7830 | Recall: 0.8279
#   car: mAP@50:95: 0.7316 | Precision: 0.6526 | Recall: 0.6685
#   motorbike: mAP@50:95: 0.6157 | Precision: 0.6000 | Recall: 0.6274
#   truck: mAP@50:95: 0.6525 | Precision: 0.7402 | Recall: 0.7870
# [Epoch 69/150] Train Loss: 0.2303 (Loc: 0.1512, Cls: 0.0700) | Val Loss: 0.1551 (Loc: 0.0950, Cls: 0.0524) | mAP@50: 0.9015 | mAP@50:95: 0.6649 | Precision (Avg): 0.3471 | Recall (Avg): 0.3641 | LR: 0.000001
#   bus: mAP@50:95: 0.6567 | Precision: 0.7832 | Recall: 0.8284
#   car: mAP@50:95: 0.7318 | Precision: 0.6526 | Recall: 0.6684
#   motorbike: mAP@50:95: 0.6165 | Precision: 0.6006 | Recall: 0.6283
#   truck: mAP@50:95: 0.6546 | Precision: 0.7403 | Recall: 0.7878
# [Epoch 70/150] Train Loss: 0.2298 (Loc: 0.1509, Cls: 0.0698) | Val Loss: 0.1549 (Loc: 0.0948, Cls: 0.0524) | mAP@50: 0.9005 | mAP@50:95: 0.6639 | Precision (Avg): 0.3469 | Recall (Avg): 0.3638 | LR: 0.000001
#   bus: mAP@50:95: 0.6540 | Precision: 0.7822 | Recall: 0.8280
#   car: mAP@50:95: 0.7313 | Precision: 0.6525 | Recall: 0.6679
#   motorbike: mAP@50:95: 0.6159 | Precision: 0.6002 | Recall: 0.6278
#   truck: mAP@50:95: 0.6544 | Precision: 0.7406 | Recall: 0.7868
# [Epoch 71/150] Train Loss: 0.2299 (Loc: 0.1508, Cls: 0.0699) | Val Loss: 0.1550 (Loc: 0.0949, Cls: 0.0524) | mAP@50: 0.9001 | mAP@50:95: 0.6632 | Precision (Avg): 0.3468 | Recall (Avg): 0.3640 | LR: 0.000001
#   bus: mAP@50:95: 0.6537 | Precision: 0.7816 | Recall: 0.8281
#   car: mAP@50:95: 0.7316 | Precision: 0.6527 | Recall: 0.6684
#   motorbike: mAP@50:95: 0.6142 | Precision: 0.5996 | Recall: 0.6275
#   truck: mAP@50:95: 0.6534 | Precision: 0.7404 | Recall: 0.7880
# [Epoch 72/150] Train Loss: 0.2301 (Loc: 0.1510, Cls: 0.0699) | Val Loss: 0.1548 (Loc: 0.0948, Cls: 0.0522) | mAP@50: 0.9005 | mAP@50:95: 0.6629 | Precision (Avg): 0.3467 | Recall (Avg): 0.3642 | LR: 0.000001
#   bus: mAP@50:95: 0.6530 | Precision: 0.7814 | Recall: 0.8289
#   car: mAP@50:95: 0.7311 | Precision: 0.6526 | Recall: 0.6681
#   motorbike: mAP@50:95: 0.6161 | Precision: 0.6000 | Recall: 0.6280
#   truck: mAP@50:95: 0.6514 | Precision: 0.7398 | Recall: 0.7882
# [Epoch 73/150] Train Loss: 0.2299 (Loc: 0.1509, Cls: 0.0698) | Val Loss: 0.1551 (Loc: 0.0949, Cls: 0.0524) | mAP@50: 0.8998 | mAP@50:95: 0.6627 | Precision (Avg): 0.3467 | Recall (Avg): 0.3641 | LR: 0.000001
#   bus: mAP@50:95: 0.6528 | Precision: 0.7803 | Recall: 0.8268
#   car: mAP@50:95: 0.7321 | Precision: 0.6527 | Recall: 0.6687
#   motorbike: mAP@50:95: 0.6148 | Precision: 0.6002 | Recall: 0.6283
#   truck: mAP@50:95: 0.6510 | Precision: 0.7402 | Recall: 0.7891
# [Epoch 74/150] Train Loss: 0.2294 (Loc: 0.1506, Cls: 0.0697) | Val Loss: 0.1550 (Loc: 0.0949, Cls: 0.0524) | mAP@50: 0.9011 | mAP@50:95: 0.6640 | Precision (Avg): 0.3470 | Recall (Avg): 0.3640 | LR: 0.000001
#   bus: mAP@50:95: 0.6553 | Precision: 0.7830 | Recall: 0.8284
#   car: mAP@50:95: 0.7313 | Precision: 0.6525 | Recall: 0.6682
#   motorbike: mAP@50:95: 0.6158 | Precision: 0.6000 | Recall: 0.6274
#   truck: mAP@50:95: 0.6537 | Precision: 0.7403 | Recall: 0.7883
# [Epoch 75/150] Train Loss: 0.2295 (Loc: 0.1506, Cls: 0.0698) | Val Loss: 0.1551 (Loc: 0.0949, Cls: 0.0525) | mAP@50: 0.9003 | mAP@50:95: 0.6631 | Precision (Avg): 0.3468 | Recall (Avg): 0.3637 | LR: 0.000001
#   bus: mAP@50:95: 0.6544 | Precision: 0.7813 | Recall: 0.8266
#   car: mAP@50:95: 0.7322 | Precision: 0.6526 | Recall: 0.6681
#   motorbike: mAP@50:95: 0.6143 | Precision: 0.6001 | Recall: 0.6270
#   bus: mAP@50:95: 0.6525 | Precision: 0.7793 | Recall: 0.8273
#   car: mAP@50:95: 0.7317 | Precision: 0.6523 | Recall: 0.6679
#   motorbike: mAP@50:95: 0.6160 | Precision: 0.6003 | Recall: 0.6279
#   truck: mAP@50:95: 0.6517 | Precision: 0.7397 | Recall: 0.7891
# [Epoch 92/150] Train Loss: 0.2270 (Loc: 0.1491, Cls: 0.0689) | Val Loss: 0.1551 (Loc: 0.0947, Cls: 0.0526) | mAP@50: 0.9001 | mAP@50:95: 0.6633 | Precision (Avg): 0.3468 | Recall (Avg): 0.3641 | LR: 0.000001
#   bus: mAP@50:95: 0.6550 | Precision: 0.7808 | Recall: 0.8269
#   car: mAP@50:95: 0.7331 | Precision: 0.6526 | Recall: 0.6681
#   motorbike: mAP@50:95: 0.6142 | Precision: 0.6004 | Recall: 0.6287
#   truck: mAP@50:95: 0.6510 | Precision: 0.7404 | Recall: 0.7893
# [Epoch 93/150] Train Loss: 0.2264 (Loc: 0.1488, Cls: 0.0688) | Val Loss: 0.1548 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.9004 | mAP@50:95: 0.6626 | Precision (Avg): 0.3467 | Recall (Avg): 0.3643 | LR: 0.000001
#   bus: mAP@50:95: 0.6534 | Precision: 0.7813 | Recall: 0.8286
#   car: mAP@50:95: 0.7321 | Precision: 0.6524 | Recall: 0.6682
#   motorbike: mAP@50:95: 0.6163 | Precision: 0.6003 | Recall: 0.6276
#   truck: mAP@50:95: 0.6487 | Precision: 0.7396 | Recall: 0.7897
# [Epoch 94/150] Train Loss: 0.2265 (Loc: 0.1489, Cls: 0.0688) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0526) | mAP@50: 0.8987 | mAP@50:95: 0.6631 | Precision (Avg): 0.3465 | Recall (Avg): 0.3639 | LR: 0.000001
#   bus: mAP@50:95: 0.6525 | Precision: 0.7799 | Recall: 0.8280
#   car: mAP@50:95: 0.7328 | Precision: 0.6508 | Recall: 0.6674
#   motorbike: mAP@50:95: 0.6158 | Precision: 0.6003 | Recall: 0.6273
#   truck: mAP@50:95: 0.6513 | Precision: 0.7411 | Recall: 0.7882
# [Epoch 95/150] Train Loss: 0.2265 (Loc: 0.1489, Cls: 0.0687) | Val Loss: 0.1547 (Loc: 0.0948, Cls: 0.0523) | mAP@50: 0.8994 | mAP@50:95: 0.6644 | Precision (Avg): 0.3465 | Recall (Avg): 0.3640 | LR: 0.000001
#   bus: mAP@50:95: 0.6556 | Precision: 0.7800 | Recall: 0.8272
#   car: mAP@50:95: 0.7333 | Precision: 0.6526 | Recall: 0.6680
#   motorbike: mAP@50:95: 0.6171 | Precision: 0.6001 | Recall: 0.6268
#   truck: mAP@50:95: 0.6514 | Precision: 0.7396 | Recall: 0.7897
# [Epoch 96/150] Train Loss: 0.2259 (Loc: 0.1485, Cls: 0.0685) | Val Loss: 0.1550 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8987 | mAP@50:95: 0.6630 | Precision (Avg): 0.3466 | Recall (Avg): 0.3638 | LR: 0.000001
#   motorbike: mAP@50:95: 0.6161 | Precision: 0.5999 | Recall: 0.6273
#   truck: mAP@50:95: 0.6508 | Precision: 0.7401 | Recall: 0.7890
# [Epoch 102/150] Train Loss: 0.2255 (Loc: 0.1483, Cls: 0.0684) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0525) | mAP@50: 0.9007 | mAP@50:95: 0.6623 | Precision (Avg): 0.3468 | Recall (Avg): 0.3641 | LR: 0.000001
#   bus: mAP@50:95: 0.6528 | Precision: 0.7816 | Recall: 0.8283
#   car: mAP@50:95: 0.7313 | Precision: 0.6523 | Recall: 0.6680
#   motorbike: mAP@50:95: 0.6158 | Precision: 0.6004 | Recall: 0.6278
#   truck: mAP@50:95: 0.6493 | Precision: 0.7399 | Recall: 0.7889
# [Epoch 103/150] Train Loss: 0.2254 (Loc: 0.1483, Cls: 0.0683) | Val Loss: 0.1546 (Loc: 0.0948, Cls: 0.0522) | mAP@50: 0.9009 | mAP@50:95: 0.6630 | Precision (Avg): 0.3469 | Recall (Avg): 0.3642 | LR: 0.000001
#   bus: mAP@50:95: 0.6550 | Precision: 0.7825 | Recall: 0.8283
#   car: mAP@50:95: 0.7326 | Precision: 0.6526 | Recall: 0.6682
#   motorbike: mAP@50:95: 0.6147 | Precision: 0.5999 | Recall: 0.6278
#   truck: mAP@50:95: 0.6495 | Precision: 0.7399 | Recall: 0.7891
# [Epoch 104/150] Train Loss: 0.2255 (Loc: 0.1481, Cls: 0.0685) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8981 | mAP@50:95: 0.6615 | Precision (Avg): 0.3463 | Recall (Avg): 0.3636 | LR: 0.000001
#   bus: mAP@50:95: 0.6516 | Precision: 0.7797 | Recall: 0.8269
#   car: mAP@50:95: 0.7301 | Precision: 0.6509 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6133 | Precision: 0.5996 | Recall: 0.6265
#   truck: mAP@50:95: 0.6510 | Precision: 0.7403 | Recall: 0.7877
# [Epoch 105/150] Train Loss: 0.2251 (Loc: 0.1481, Cls: 0.0682) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0525) | mAP@50: 0.8994 | mAP@50:95: 0.6627 | Precision (Avg): 0.3465 | Recall (Avg): 0.3635 | LR: 0.000001
#   bus: mAP@50:95: 0.6540 | Precision: 0.7810 | Recall: 0.8255
#   car: mAP@50:95: 0.7318 | Precision: 0.6523 | Recall: 0.6677
#   motorbike: mAP@50:95: 0.6146 | Precision: 0.5997 | Recall: 0.6266
#   truck: mAP@50:95: 0.6505 | Precision: 0.7392 | Recall: 0.7883
# [Epoch 106/150] Train Loss: 0.2251 (Loc: 0.1479, Cls: 0.0683) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8987 | mAP@50:95: 0.6636 | Precision (Avg): 0.3465 | Recall (Avg): 0.3635 | LR: 0.000001
#   bus: mAP@50:95: 0.6540 | Precision: 0.7801 | Recall: 0.8253
#   car: mAP@50:95: 0.7318 | Precision: 0.6508 | Recall: 0.6673
#   car: mAP@50:95: 0.7324 | Precision: 0.6522 | Recall: 0.6680
#   motorbike: mAP@50:95: 0.6154 | Precision: 0.5997 | Recall: 0.6267
#   truck: mAP@50:95: 0.6507 | Precision: 0.7399 | Recall: 0.7880
# [Epoch 117/150] Train Loss: 0.2238 (Loc: 0.1472, Cls: 0.0679) | Val Loss: 0.1551 (Loc: 0.0948, Cls: 0.0525) | mAP@50: 0.9000 | mAP@50:95: 0.6633 | Precision (Avg): 0.3467 | Recall (Avg): 0.3637 | LR: 0.000001
#   bus: mAP@50:95: 0.6547 | Precision: 0.7816 | Recall: 0.8266
#   car: mAP@50:95: 0.7320 | Precision: 0.6526 | Recall: 0.6679
#   motorbike: mAP@50:95: 0.6157 | Precision: 0.5998 | Recall: 0.6271
#   truck: mAP@50:95: 0.6509 | Precision: 0.7399 | Recall: 0.7880
# [Epoch 118/150] Train Loss: 0.2237 (Loc: 0.1473, Cls: 0.0677) | Val Loss: 0.1550 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8983 | mAP@50:95: 0.6626 | Precision (Avg): 0.3464 | Recall (Avg): 0.3635 | LR: 0.000001
#   bus: mAP@50:95: 0.6535 | Precision: 0.7797 | Recall: 0.8266
#   car: mAP@50:95: 0.7317 | Precision: 0.6508 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6148 | Precision: 0.5999 | Recall: 0.6262
#   truck: mAP@50:95: 0.6506 | Precision: 0.7404 | Recall: 0.7880
# [Epoch 119/150] Train Loss: 0.2233 (Loc: 0.1471, Cls: 0.0675) | Val Loss: 0.1551 (Loc: 0.0949, Cls: 0.0524) | mAP@50: 0.8999 | mAP@50:95: 0.6615 | Precision (Avg): 0.3465 | Recall (Avg): 0.3640 | LR: 0.000001
#   bus: mAP@50:95: 0.6513 | Precision: 0.7801 | Recall: 0.8280
#   car: mAP@50:95: 0.7314 | Precision: 0.6524 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6159 | Precision: 0.6000 | Recall: 0.6277
#   truck: mAP@50:95: 0.6472 | Precision: 0.7392 | Recall: 0.7887
# [Epoch 120/150] Train Loss: 0.2234 (Loc: 0.1470, Cls: 0.0676) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0523) | mAP@50: 0.8999 | mAP@50:95: 0.6624 | Precision (Avg): 0.3467 | Recall (Avg): 0.3639 | LR: 0.000001
#   bus: mAP@50:95: 0.6508 | Precision: 0.7812 | Recall: 0.8275
#   car: mAP@50:95: 0.7325 | Precision: 0.6524 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6155 | Precision: 0.5995 | Recall: 0.6273
#   truck: mAP@50:95: 0.6509 | Precision: 0.7405 | Recall: 0.7884
# [Epoch 121/150] Train Loss: 0.2235 (Loc: 0.1472, Cls: 0.0676) | Val Loss: 0.1551 (Loc: 0.0947, Cls: 0.0526) | mAP@50: 0.8984 | mAP@50:95: 0.6625 | Precision (Avg): 0.3464 | Recall (Avg): 0.3636 | LR: 0.000001
#   bus: mAP@50:95: 0.6509 | Precision: 0.7796 | Recall: 0.8266
#   car: mAP@50:95: 0.7315 | Precision: 0.6523 | Recall: 0.6681
#   motorbike: mAP@50:95: 0.6158 | Precision: 0.6000 | Recall: 0.6270
#   truck: mAP@50:95: 0.6493 | Precision: 0.7388 | Recall: 0.7892
# [Epoch 127/150] Train Loss: 0.2226 (Loc: 0.1467, Cls: 0.0673) | Val Loss: 0.1547 (Loc: 0.0947, Cls: 0.0523) | mAP@50: 0.8981 | mAP@50:95: 0.6615 | Precision (Avg): 0.3463 | Recall (Avg): 0.3637 | LR: 0.000001
#   bus: mAP@50:95: 0.6530 | Precision: 0.7812 | Recall: 0.8268
#   car: mAP@50:95: 0.7313 | Precision: 0.6506 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6142 | Precision: 0.5996 | Recall: 0.6274
#   truck: mAP@50:95: 0.6475 | Precision: 0.7389 | Recall: 0.7878
# [Epoch 128/150] Train Loss: 0.2226 (Loc: 0.1465, Cls: 0.0674) | Val Loss: 0.1551 (Loc: 0.0947, Cls: 0.0528) | mAP@50: 0.8998 | mAP@50:95: 0.6628 | Precision (Avg): 0.3466 | Recall (Avg): 0.3634 | LR: 0.000001
#   bus: mAP@50:95: 0.6522 | Precision: 0.7800 | Recall: 0.8256
#   car: mAP@50:95: 0.7324 | Precision: 0.6526 | Recall: 0.6677
#   motorbike: mAP@50:95: 0.6154 | Precision: 0.5995 | Recall: 0.6264
#   truck: mAP@50:95: 0.6512 | Precision: 0.7405 | Recall: 0.7873
# [Epoch 129/150] Train Loss: 0.2226 (Loc: 0.1465, Cls: 0.0675) | Val Loss: 0.1553 (Loc: 0.0948, Cls: 0.0527) | mAP@50: 0.8991 | mAP@50:95: 0.6622 | Precision (Avg): 0.3464 | Recall (Avg): 0.3637 | LR: 0.000001
#   bus: mAP@50:95: 0.6527 | Precision: 0.7798 | Recall: 0.8260
#   car: mAP@50:95: 0.7319 | Precision: 0.6522 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6157 | Precision: 0.5997 | Recall: 0.6270
#   truck: mAP@50:95: 0.6486 | Precision: 0.7396 | Recall: 0.7886
# [Epoch 130/150] Train Loss: 0.2224 (Loc: 0.1464, Cls: 0.0674) | Val Loss: 0.1546 (Loc: 0.0947, Cls: 0.0521) | mAP@50: 0.8991 | mAP@50:95: 0.6622 | Precision (Avg): 0.3463 | Recall (Avg): 0.3636 | LR: 0.000001
#   bus: mAP@50:95: 0.6531 | Precision: 0.7795 | Recall: 0.8249
#   car: mAP@50:95: 0.7317 | Precision: 0.6524 | Recall: 0.6679
#   motorbike: mAP@50:95: 0.6150 | Precision: 0.5993 | Recall: 0.6273
#   truck: mAP@50:95: 0.6491 | Precision: 0.7395 | Recall: 0.7885
# [Epoch 131/150] Train Loss: 0.2225 (Loc: 0.1465, Cls: 0.0674) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8981 | mAP@50:95: 0.6611 | Precision (Avg): 0.3463 | Recall (Avg): 0.3636 | LR: 0.000001
#   bus: mAP@50:95: 0.6497 | Precision: 0.7791 | Recall: 0.8264
#   car: mAP@50:95: 0.7308 | Precision: 0.6506 | Recall: 0.6676
#   motorbike: mAP@50:95: 0.6155 | Precision: 0.6000 | Recall: 0.6270
#   truck: mAP@50:95: 0.6483 | Precision: 0.7403 | Recall: 0.7881
# [Epoch 132/150] Train Loss: 0.2223 (Loc: 0.1463, Cls: 0.0673) | Val Loss: 0.1549 (Loc: 0.0948, Cls: 0.0525) | mAP@50: 0.8980 | mAP@50:95: 0.6618 | Precision (Avg): 0.3462 | Recall (Avg): 0.3634 | LR: 0.000001
#   bus: mAP@50:95: 0.6499 | Precision: 0.7795 | Recall: 0.8249
#   car: mAP@50:95: 0.7313 | Precision: 0.6506 | Recall: 0.6672
#   motorbike: mAP@50:95: 0.6159 | Precision: 0.5998 | Recall: 0.6272
#   truck: mAP@50:95: 0.6500 | Precision: 0.7397 | Recall: 0.7880
# [Epoch 133/150] Train Loss: 0.2218 (Loc: 0.1460, Cls: 0.0672) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8991 | mAP@50:95: 0.6626 | Precision (Avg): 0.3464 | Recall (Avg): 0.3636 | LR: 0.000001
#   bus: mAP@50:95: 0.6540 | Precision: 0.7807 | Recall: 0.8263
#   car: mAP@50:95: 0.7325 | Precision: 0.6523 | Recall: 0.6682
#   motorbike: mAP@50:95: 0.6154 | Precision: 0.5995 | Recall: 0.6270
#   truck: mAP@50:95: 0.6485 | Precision: 0.7387 | Recall: 0.7871
# [Epoch 134/150] Train Loss: 0.2220 (Loc: 0.1462, Cls: 0.0672) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8989 | mAP@50:95: 0.6628 | Precision (Avg): 0.3465 | Recall (Avg): 0.3631 | LR: 0.000001
#   bus: mAP@50:95: 0.6537 | Precision: 0.7805 | Recall: 0.8234
#   car: mAP@50:95: 0.7308 | Precision: 0.6508 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6138 | Precision: 0.5997 | Recall: 0.6261
#   truck: mAP@50:95: 0.6526 | Precision: 0.7412 | Recall: 0.7881
# [Epoch 135/150] Train Loss: 0.2215 (Loc: 0.1459, Cls: 0.0670) | Val Loss: 0.1549 (Loc: 0.0948, Cls: 0.0526) | mAP@50: 0.8995 | mAP@50:95: 0.6619 | Precision (Avg): 0.3465 | Recall (Avg): 0.3632 | LR: 0.000001
#   bus: mAP@50:95: 0.6495 | Precision: 0.7798 | Recall: 0.8242
#   car: mAP@50:95: 0.7323 | Precision: 0.6524 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6149 | Precision: 0.5997 | Recall: 0.6265
#   truck: mAP@50:95: 0.6508 | Precision: 0.7402 | Recall: 0.7870
# [Epoch 136/150] Train Loss: 0.2220 (Loc: 0.1460, Cls: 0.0673) | Val Loss: 0.1548 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8977 | mAP@50:95: 0.6612 | Precision (Avg): 0.3461 | Recall (Avg): 0.3633 | LR: 0.000001
#   bus: mAP@50:95: 0.6511 | Precision: 0.7802 | Recall: 0.8246
#   car: mAP@50:95: 0.7307 | Precision: 0.6505 | Recall: 0.6676
#   motorbike: mAP@50:95: 0.6145 | Precision: 0.5995 | Recall: 0.6265
#   truck: mAP@50:95: 0.6485 | Precision: 0.7385 | Recall: 0.7876
# [Epoch 137/150] Train Loss: 0.2212 (Loc: 0.1458, Cls: 0.0669) | Val Loss: 0.1547 (Loc: 0.0946, Cls: 0.0523) | mAP@50: 0.8981 | mAP@50:95: 0.6611 | Precision (Avg): 0.3461 | Recall (Avg): 0.3633 | LR: 0.000001
#   bus: mAP@50:95: 0.6510 | Precision: 0.7808 | Recall: 0.8264
#   car: mAP@50:95: 0.7309 | Precision: 0.6507 | Recall: 0.6677
#   motorbike: mAP@50:95: 0.6143 | Precision: 0.5990 | Recall: 0.6257
#   truck: mAP@50:95: 0.6483 | Precision: 0.7383 | Recall: 0.7864
# [Epoch 138/150] Train Loss: 0.2212 (Loc: 0.1457, Cls: 0.0669) | Val Loss: 0.1547 (Loc: 0.0946, Cls: 0.0523) | mAP@50: 0.8967 | mAP@50:95: 0.6600 | Precision (Avg): 0.3457 | Recall (Avg): 0.3634 | LR: 0.000001
#   bus: mAP@50:95: 0.6473 | Precision: 0.7782 | Recall: 0.8253
#   car: mAP@50:95: 0.7314 | Precision: 0.6505 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6154 | Precision: 0.5993 | Recall: 0.6267
#   truck: mAP@50:95: 0.6459 | Precision: 0.7377 | Recall: 0.7872
# [Epoch 139/150] Train Loss: 0.2210 (Loc: 0.1456, Cls: 0.0668) | Val Loss: 0.1548 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8983 | mAP@50:95: 0.6617 | Precision (Avg): 0.3463 | Recall (Avg): 0.3633 | LR: 0.000001
#   bus: mAP@50:95: 0.6526 | Precision: 0.7801 | Recall: 0.8255
#   car: mAP@50:95: 0.7315 | Precision: 0.6510 | Recall: 0.6677
#   motorbike: mAP@50:95: 0.6153 | Precision: 0.5992 | Recall: 0.6260
#   truck: mAP@50:95: 0.6475 | Precision: 0.7399 | Recall: 0.7871
# [Epoch 140/150] Train Loss: 0.2216 (Loc: 0.1460, Cls: 0.0670) | Val Loss: 0.1547 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8988 | mAP@50:95: 0.6602 | Precision (Avg): 0.3463 | Recall (Avg): 0.3632 | LR: 0.000001
#   bus: mAP@50:95: 0.6473 | Precision: 0.7796 | Recall: 0.8240
#   car: mAP@50:95: 0.7317 | Precision: 0.6523 | Recall: 0.6681
#   motorbike: mAP@50:95: 0.6136 | Precision: 0.5994 | Recall: 0.6264
#   truck: mAP@50:95: 0.6481 | Precision: 0.7389 | Recall: 0.7871
# [Epoch 141/150] Train Loss: 0.2212 (Loc: 0.1456, Cls: 0.0670) | Val Loss: 0.1550 (Loc: 0.0948, Cls: 0.0526) | mAP@50: 0.8995 | mAP@50:95: 0.6614 | Precision (Avg): 0.3465 | Recall (Avg): 0.3633 | LR: 0.000001
#   bus: mAP@50:95: 0.6510 | Precision: 0.7810 | Recall: 0.8249
#   car: mAP@50:95: 0.7312 | Precision: 0.6524 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6144 | Precision: 0.5992 | Recall: 0.6263
#   truck: mAP@50:95: 0.6490 | Precision: 0.7395 | Recall: 0.7870
# [Epoch 142/150] Train Loss: 0.2211 (Loc: 0.1456, Cls: 0.0670) | Val Loss: 0.1550 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8979 | mAP@50:95: 0.6608 | Precision (Avg): 0.3460 | Recall (Avg): 0.3631 | LR: 0.000001
#   bus: mAP@50:95: 0.6475 | Precision: 0.7795 | Recall: 0.8246
#   car: mAP@50:95: 0.7314 | Precision: 0.6508 | Recall: 0.6673
#   motorbike: mAP@50:95: 0.6153 | Precision: 0.5995 | Recall: 0.6267
#   truck: mAP@50:95: 0.6490 | Precision: 0.7383 | Recall: 0.7862
# [Epoch 143/150] Train Loss: 0.2214 (Loc: 0.1457, Cls: 0.0670) | Val Loss: 0.1546 (Loc: 0.0948, Cls: 0.0523) | mAP@50: 0.8981 | mAP@50:95: 0.6605 | Precision (Avg): 0.3462 | Recall (Avg): 0.3632 | LR: 0.000001
#   bus: mAP@50:95: 0.6489 | Precision: 0.7804 | Recall: 0.8250
#   car: mAP@50:95: 0.7303 | Precision: 0.6508 | Recall: 0.6674
#   motorbike: mAP@50:95: 0.6149 | Precision: 0.5995 | Recall: 0.6259
#   truck: mAP@50:95: 0.6479 | Precision: 0.7391 | Recall: 0.7874
# [Epoch 144/150] Train Loss: 0.2207 (Loc: 0.1455, Cls: 0.0667) | Val Loss: 0.1546 (Loc: 0.0946, Cls: 0.0523) | mAP@50: 0.8976 | mAP@50:95: 0.6604 | Precision (Avg): 0.3461 | Recall (Avg): 0.3633 | LR: 0.000001
#   bus: mAP@50:95: 0.6477 | Precision: 0.7803 | Recall: 0.8263
#   car: mAP@50:95: 0.7309 | Precision: 0.6506 | Recall: 0.6677
#   motorbike: mAP@50:95: 0.6146 | Precision: 0.5988 | Recall: 0.6260
#   truck: mAP@50:95: 0.6482 | Precision: 0.7389 | Recall: 0.7868
# [Epoch 145/150] Train Loss: 0.2208 (Loc: 0.1454, Cls: 0.0667) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0526) | mAP@50: 0.8983 | mAP@50:95: 0.6607 | Precision (Avg): 0.3463 | Recall (Avg): 0.3630 | LR: 0.000001
#   bus: mAP@50:95: 0.6495 | Precision: 0.7804 | Recall: 0.8242
#   car: mAP@50:95: 0.7298 | Precision: 0.6506 | Recall: 0.6673
#   motorbike: mAP@50:95: 0.6150 | Precision: 0.5994 | Recall: 0.6259
#   truck: mAP@50:95: 0.6485 | Precision: 0.7401 | Recall: 0.7863
# [Epoch 146/150] Train Loss: 0.2212 (Loc: 0.1458, Cls: 0.0669) | Val Loss: 0.1548 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8978 | mAP@50:95: 0.6605 | Precision (Avg): 0.3461 | Recall (Avg): 0.3632 | LR: 0.000001
#   bus: mAP@50:95: 0.6501 | Precision: 0.7805 | Recall: 0.8251
#   car: mAP@50:95: 0.7295 | Precision: 0.6506 | Recall: 0.6678
#   motorbike: mAP@50:95: 0.6148 | Precision: 0.5992 | Recall: 0.6261
#   truck: mAP@50:95: 0.6479 | Precision: 0.7389 | Recall: 0.7870
# [Epoch 147/150] Train Loss: 0.2205 (Loc: 0.1453, Cls: 0.0667) | Val Loss: 0.1549 (Loc: 0.0947, Cls: 0.0525) | mAP@50: 0.8978 | mAP@50:95: 0.6598 | Precision (Avg): 0.3461 | Recall (Avg): 0.3635 | LR: 0.000001
#   bus: mAP@50:95: 0.6470 | Precision: 0.7805 | Recall: 0.8271
#   car: mAP@50:95: 0.7302 | Precision: 0.6506 | Recall: 0.6674
#   motorbike: mAP@50:95: 0.6145 | Precision: 0.5993 | Recall: 0.6267
#   truck: mAP@50:95: 0.6476 | Precision: 0.7386 | Recall: 0.7870
# [Epoch 148/150] Train Loss: 0.2205 (Loc: 0.1452, Cls: 0.0668) | Val Loss: 0.1551 (Loc: 0.0947, Cls: 0.0526) | mAP@50: 0.8978 | mAP@50:95: 0.6616 | Precision (Avg): 0.3459 | Recall (Avg): 0.3632 | LR: 0.000001
#   bus: mAP@50:95: 0.6502 | Precision: 0.7796 | Recall: 0.8241
#   car: mAP@50:95: 0.7308 | Precision: 0.6506 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6155 | Precision: 0.5995 | Recall: 0.6273
#   truck: mAP@50:95: 0.6499 | Precision: 0.7378 | Recall: 0.7863
# [Epoch 149/150] Train Loss: 0.2205 (Loc: 0.1453, Cls: 0.0667) | Val Loss: 0.1547 (Loc: 0.0947, Cls: 0.0524) | mAP@50: 0.8977 | mAP@50:95: 0.6599 | Precision (Avg): 0.3459 | Recall (Avg): 0.3629 | LR: 0.000001
#   bus: mAP@50:95: 0.6481 | Precision: 0.7802 | Recall: 0.8240
#   car: mAP@50:95: 0.7284 | Precision: 0.6504 | Recall: 0.6669
#   motorbike: mAP@50:95: 0.6145 | Precision: 0.5994 | Recall: 0.6263
#   truck: mAP@50:95: 0.6486 | Precision: 0.7373 | Recall: 0.7858
# [Epoch 150/150] Train Loss: 0.2204 (Loc: 0.1452, Cls: 0.0667) | Val Loss: 0.1549 (Loc: 0.0946, Cls: 0.0526) | mAP@50: 0.8987 | mAP@50:95: 0.6605 | Precision (Avg): 0.3462 | Recall (Avg): 0.3635 | LR: 0.000001
#   bus: mAP@50:95: 0.6486 | Precision: 0.7802 | Recall: 0.8266
#   car: mAP@50:95: 0.7310 | Precision: 0.6520 | Recall: 0.6675
#   motorbike: mAP@50:95: 0.6140 | Precision: 0.5991 | Recall: 0.6259
#   truck: mAP@50:95: 0.6485 | Precision: 0.7383 | Recall: 0.7880
